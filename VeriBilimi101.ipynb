# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
data = pd.read_csv('./wc_champions.csv')

# %%
data
# Out:
#     Unnamed: 0 champion  sum_total  win_total  lose_total pick_rate  \
# 0            0   Graves         69         35          34    50.72%
# 1            1    Senna         46         21          25    45.65%
# 2            2     Jhin         42         28          14    66.67%
# 3            3    Leona         42         26          16    61.90%
# 4            4     Ashe         42         17          25    40.48%
# ..         ...      ...        ...        ...         ...       ...
# 83          83    Poppy          1          0           1     0.00%
# 84          84    Quinn          1          0           1     0.00%
# 85          85     Ryze          1          0           1     0.00%
# 86          86  Skarner          1          0           1     0.00%
# 87          87    Xayah          1          0           1     0.00%
#
#    winrate_total  sum_blue_side  win_blue_side  lose_blue_side  \
# 0         60.53%             34             17              17
# ...

# %%
data.head()
# Out:
#    Unnamed: 0 champion  sum_total  win_total  lose_total pick_rate  \
# 0           0   Graves         69         35          34    50.72%
# 1           1    Senna         46         21          25    45.65%
# 2           2     Jhin         42         28          14    66.67%
# 3           3    Leona         42         26          16    61.90%
# 4           4     Ashe         42         17          25    40.48%
#
#   winrate_total  sum_blue_side  win_blue_side  lose_blue_side  \
# 0        60.53%             34             17              17
# 1        40.35%             21             12               9
# 2        36.84%             20             10              10
# 3        36.84%             19             14               5
# 4        36.84%             15              5              10
#
#   winrate_blue_side  sum_red_side  win_red_side  lose_red_side  \
# 0            50.00%            35            18             17
# ...

# %%
data.tail()
# Out:
#     Unnamed: 0 champion  sum_total  win_total  lose_total pick_rate  \
# 83          83    Poppy          1          0           1     0.00%
# 84          84    Quinn          1          0           1     0.00%
# 85          85     Ryze          1          0           1     0.00%
# 86          86  Skarner          1          0           1     0.00%
# 87          87    Xayah          1          0           1     0.00%
#
#    winrate_total  sum_blue_side  win_blue_side  lose_blue_side  \
# 83         0.88%              1              0               1
# 84         0.88%              0              0               0
# 85         0.88%              0              0               0
# 86         0.88%              0              0               0
# 87         0.88%              0              0               0
#
#    winrate_blue_side  sum_red_side  win_red_side  lose_red_side  \
# 83             0.00%             0             0              0
# ...

# %%
data.describe()
# Out:
#        Unnamed: 0  sum_total  win_total  lose_total  sum_blue_side  \
# count   88.000000  88.000000  88.000000   88.000000      88.000000
# mean    43.500000  12.977273   6.500000    6.477273       6.477273
# std     25.547342  14.016392   7.626331    6.899904       6.972816
# min      0.000000   1.000000   0.000000    0.000000       0.000000
# 25%     21.750000   2.000000   1.000000    1.000000       1.000000
# 50%     43.500000   7.500000   4.000000    4.000000       5.000000
# 75%     65.250000  17.250000   9.000000    9.000000      10.250000
# max     87.000000  69.000000  35.000000   34.000000      34.000000
#
#        win_blue_side  lose_blue_side  sum_red_side  win_red_side  \
# count      88.000000       88.000000     88.000000     88.000000
# mean        3.295455        3.181818      6.500000      3.204545
# std         4.011934        3.385383      7.471017      4.020519
# min         0.000000        0.000000      0.000000      0.000000
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 88 entries, 0 to 87
# Data columns (total 15 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Unnamed: 0         88 non-null     int64
#  1   champion           88 non-null     object
#  2   sum_total          88 non-null     int64
#  3   win_total          88 non-null     int64
#  4   lose_total         88 non-null     int64
#  5   pick_rate          88 non-null     object
#  6   winrate_total      88 non-null     object
#  7   sum_blue_side      88 non-null     int64
#  8   win_blue_side      88 non-null     int64
#  9   lose_blue_side     88 non-null     int64
#  10  winrate_blue_side  88 non-null     object
#  11  sum_red_side       88 non-null     int64
#  12  win_red_side       88 non-null     int64
#  13  lose_red_side      88 non-null     int64
#  14  winrate_red_side   88 non-null     object
# dtypes: int64(10), object(5)
# memory usage: 10.4+ KB

# %%
data.hist(bins=50,figsize=(20,15))
plt.show()

# %%
missing_data_count = data.isnull().sum()
missing_data_count
# Out:
# Unnamed: 0           0
# champion             0
# sum_total            0
# win_total            0
# lose_total           0
# pick_rate            0
# winrate_total        0
# sum_blue_side        0
# win_blue_side        0
# lose_blue_side       0
# winrate_blue_side    0
# sum_red_side         0
# win_red_side         0
# lose_red_side        0
# winrate_red_side     0
# dtype: int64

# %%
data.iloc[0]
# Out:
# Unnamed: 0                0
# champion             Graves
# sum_total                69
# win_total                35
# lose_total               34
# pick_rate            50.72%
# winrate_total        60.53%
# sum_blue_side            34
# win_blue_side            17
# lose_blue_side           17
# winrate_blue_side    50.00%
# sum_red_side             35
# win_red_side             18
# lose_red_side            17
# winrate_red_side     51.43%
# Name: 0, dtype: object

# %%
data.shape
# Out:
# (88, 15)
